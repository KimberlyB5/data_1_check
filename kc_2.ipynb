# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
Mpox = pd.read_csv(os.path.join("C:\\Users\\kam52\\OneDrive\\Desktop\\DA1\\data_1_check\\Monkeypox.csv"))
Mpox
# Out:
#           ID     Status                             Location    City  \
# 0        1.0  confirmed  Guy's and St Thomas Hospital London  London
# 1        2.0  confirmed  Guy's and St Thomas Hospital London  London
# 2        3.0  confirmed                               London  London
# 3        4.0  confirmed                               London  London
# 4        5.0  confirmed                               London  London
# ...      ...        ...                                  ...     ...
# 1128  1128.0  discarded                                  NaN     NaN
# 1129  1129.0  discarded                                  NaN     NaN
# 1130  1130.0  discarded                                  NaN     NaN
# 1131  1131.0  discarded                                  NaN     NaN
# 1132  1132.0  discarded                                  NaN     NaN
#
#        Country  Age Gender  Date_onset Date_confirmation        Symptoms  ...  \
# ...

# %%
df = pd.read_csv("C:\\Users\\kam52\\OneDrive\\Desktop\\DA1\\data_1_check\\Monkeypox.csv", usecols = ['Status','Country'])
print(df)
# Out:
#          Status   Country
# 0     confirmed   England
# 1     confirmed   England
# 2     confirmed   England
# 3     confirmed   England
# 4     confirmed   England
# ...         ...       ...
# 1128  discarded  Thailand
# 1129  discarded  Thailand
# 1130  discarded  Thailand
# 1131  discarded  Thailand
# 1132  discarded  Thailand
#
# [1133 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.unique(df['Country'])
# Out:
# array(['England', 'Portugal', 'Spain', 'United States', 'Canada',
#        'Sweden', 'Italy', 'France', 'Belgium', 'Australia', 'Germany',
#        'Netherlands', 'Israel', 'Switzerland', 'Greece', 'Austria',
#        'Argentina', 'Denmark', 'Morocco', 'Slovenia', 'Scotland',
#        'Czech Republic', 'United Arab Emirates', 'Finland', 'Wales',
#        'Northern Ireland', 'Sudan', 'Bolivia', 'Iran', 'Ecuador', 'Malta',
#        'Ireland', 'Mexico', 'Pakistan', 'French Guiana', 'Thailand',
#        'Peru', 'Brazil', 'Malaysia', 'Hungary', 'Norway', 'Paraguay',
#        'Costa Rica', 'United Kingdom', 'Mauritius', 'Haiti', 'Uruguay',
#        'Latvia', nan, 'Cayman Islands'], dtype=object)

# %%
country_group= df.groupby('Country').count()
print(country_group)
# Out:
#                       Status
# Country
# Argentina                  2
# Australia                  7
# Austria                    1
# Belgium                   17
# Bolivia                    3
# Brazil                     4
# Canada                    97
# Cayman Islands             1
# Costa Rica                 1
# Czech Republic             6
# Denmark                    2
# Ecuador                    1
# England                  214
# Finland                    2
# France                    51
# French Guiana              2
# Germany                   66
# Greece                     1
# Haiti                      1
# Hungary                    1
# Iran                       6
# Ireland                    6
# Israel                     4
# Italy                     29
# Latvia                     1
# Malaysia                   3
# Malta                      1
# Mauritius                  3
# Mexico                     1
# Morocco                    4
# ...

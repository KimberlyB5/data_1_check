# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(os.path.join("https://query.data.world/s/ti4reepebaxvozsotydx6vm3nyqz3u"))
df
# Out:
#                                                   summary          city state  \
# 0       Viewed some red lights in the sky appearing to...       Visalia    CA
# 1       Look like 1 or 3 crafts from North traveling s...    Cincinnati    OH
# 2       seen dark rectangle moving slowly thru the sky...        Tecopa    CA
# 3       One red light moving switly west to east, beco...     Knoxville    TN
# 4       Bright, circular Fresnel-lens shaped light sev...    Alexandria    VA
# ...                                                   ...           ...   ...
# 136935  Huge black triangle with 3-4 lights on the sid...     Kennewick    WA
# 136936  It was a cylinder shaped craft that appeared o...     Kissimmee    FL
# 136937  Beautiful lights flying intimately over the so...        Denver    CO
# 136938  3/15/21 in Mojave area fwy 14 or 58, close to ...        Mojave    CA
# 136939  Miller State Park UFO sighting, 900sqf object ...  Peterborough    NH
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# summary            object
# city               object
# state              object
# date_time          object
# shape              object
# duration           object
# stats              object
# report_link        object
# text               object
# posted             object
# city_latitude     float64
# city_longitude    float64
# dtype: object

# %%
#To count how many sightings per state
def state():
    ds = pd.read_csv(os.path.join("https://query.data.world/s/ti4reepebaxvozsotydx6vm3nyqz3u"),
        usecols = ['city', 'state'])
    state_city= ds.groupby('state').count()
    return state_city
  
state()
# Out:
#             city
# state
# AB           649
# AK           612
# AL          1252
# ALBERTA        1
# AR          1165
# ...          ...
# WARRINGTON     1
# WI          2292
# WV           849
# WY           381
# YT            34
#
# [86 rows x 1 columns]

# %%
#To plot data from state() on graph

def state_graph():
    ds = pd.read_csv(os.path.join("https://query.data.world/s/ti4reepebaxvozsotydx6vm3nyqz3u"),
        usecols = ['city', 'state'])
    state_city= ds.groupby('state').count()
    state_city.plot (kind ='bar', figsize=(18,9))
    plt.xlabel('State or Country')
    plt.ylabel('Sightings Reported')
    
state_graph()

# %%
#What shapes are the most reported
def ms():
    ds = pd.read_csv(os.path.join("https://query.data.world/s/ti4reepebaxvozsotydx6vm3nyqz3u"))
    shapes = df.groupby(['shape'])['shape'].count()
    return shapes

ms()
# Out:
# shape
# changed          1
# changing      3348
# chevron       1574
# cigar         3350
# circle       14438
# cone           545
# crescent         2
# cross          439
# cylinder      2138
# delta           11
# diamond       1978
# disk          8127
# dome             1
# egg           1182
# fireball      9602
# flare            1
# flash         2398
# formation     4568
# hexagon          1
# light        27871
# other         9412
# oval          5944
# pyramid          1
# rectangle     2348
# round            2
# sphere        8912
# teardrop      1183
# triangle     12323
# unknown       9318
# Name: shape, dtype: int64
